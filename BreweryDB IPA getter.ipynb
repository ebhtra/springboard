# %%
import pandas as pd
import requests
import json
# Assign private constants from a separate file, for API calls to brewerydb and untappd
from api_keys import prodKEY, prodURL, untappd_ID, untappd_SECRET, untappd_URL

# %% [markdown]
# ### Start by getting all beer styles listed on breweryDB

# %%
all_styles = requests.get(prodURL + 'styles?key=' + prodKEY).json()
# parse that JSON response into a readable list
style_list = [(style['id'], style['name']) for style in all_styles['data']]

print(len(style_list))
style_list
# Out:
# 181
# [(1, 'Classic English-Style Pale Ale'),
#  (2, 'English-Style India Pale Ale'),
#  (3, 'Ordinary Bitter'),
#  (4, 'Special Bitter or Best Bitter'),
#  (5, 'Extra Special Bitter'),
#  (6, 'English-Style Summer Ale'),
#  (7, 'Scottish-Style Light Ale'),
#  (8, 'Scottish-Style Heavy Ale'),
#  (9, 'Scottish-Style Export Ale'),
#  (10, 'English-Style Pale Mild Ale'),
#  (11, 'English-Style Dark Mild Ale'),
#  (12, 'English-Style Brown Ale'),
#  (13, 'Old Ale'),
#  (14, 'Strong Ale'),
#  (15, 'Scotch Ale'),
#  (16, 'British-Style Imperial Stout'),
#  (17, 'British-Style Barley Wine Ale'),
#  (18, 'Brown Porter'),
#  (19, 'Robust Porter'),
#  (20, 'Sweet or Cream Stout'),
#  (21, 'Oatmeal Stout'),
#  (22, 'Irish-Style Red Ale'),
#  (23, 'Classic Irish-Style Dry Stout'),
#  (24, 'Foreign (Export)-Style Stout'),
#  (25, 'American-Style Pale Ale'),
#  (26, 'Fresh "Wet" Hop Ale'),
#  (27, 'Pale American-Belgo-Style Ale'),
#  (28, 'Dark American-Belgo-Style Ale'),
#  (29, 'American-Style Strong Pale Ale'),
#  (30, 'American-Style India Pale Ale'),
#  (31, 'Imperial or Double India Pale Ale'),
#  (32, 'American-Style Amber/Red Ale'),
#  (33, 'Imperial Red Ale'),
#  (34, 'American-Style Barley Wine Ale'),
#  (35, 'American-Style Wheat Wine Ale'),
#  (36, 'Golden or Blonde Ale'),
#  (37, 'American-Style Brown Ale'),
#  (38, 'Smoke Porter'),
#  (39, 'Brett Beer'),
#  (40, 'American-Style Sour Ale'),
#  (41, 'American-Style Black Ale'),
#  (42, 'American-Style Stout'),
#  (43, 'American-Style Imperial Stout'),
#  (44, 'Specialty Stouts'),
#  (45, 'German-Style Kölsch / Köln-Style Kölsch'),
#  (46, 'Berliner-Style Weisse (Wheat)'),
#  (47, 'Leipzig-Style Gose'),
#  (48, 'South German-Style Hefeweizen / Hefeweissbier'),
#  (49, 'South German-Style Kristall Weizen / Kristall Weissbier'),
#  (50, 'German-Style Leichtes Weizen / Weissbier'),
#  (51, 'South German-Style Bernsteinfarbenes Weizen / Weissbier'),
#  (52, 'South German-Style Dunkel Weizen / Dunkel Weissbier'),
#  (53, 'South German-Style Weizenbock / Weissbock'),
#  (54, 'Bamberg-Style Weiss (Smoke) Rauchbier (Dunkel or Helles)'),
#  (55, 'German-Style Altbier'),
#  (56, 'Kellerbier (Cellar beer) or Zwickelbier - Ale'),
#  (57, 'Belgian-Style Flanders Oud Bruin or Oud Red Ales'),
#  (58, 'Belgian-Style Dubbel'),
#  (59, 'Belgian-Style Tripel'),
#  (60, 'Belgian-Style Quadrupel'),
#  (61, 'Belgian-Style Blonde Ale'),
#  (62, 'Belgian-Style Pale Ale'),
#  (63, 'Belgian-Style Pale Strong Ale'),
#  (64, 'Belgian-Style Dark Strong Ale'),
#  (65, 'Belgian-Style White (or Wit) / Belgian-Style Wheat'),
#  (66, 'Belgian-Style Lambic'),
#  (67, 'Belgian-Style Gueuze Lambic'),
#  (68, 'Belgian-Style Fruit Lambic'),
#  (69, 'Belgian-Style Table Beer'),
#  (70, 'Other Belgian-Style Ales'),
#  (71, 'French-Style Bière de Garde'),
#  (72, 'French & Belgian-Style Saison'),
#  (73, 'International-Style Pale Ale'),
#  (74, 'Australian-Style Pale Ale'),
#  (75, 'German-Style Pilsener'),
#  (76, 'Bohemian-Style Pilsener'),
#  (77, 'German-Style Leichtbier'),
#  (78, 'Münchner (Munich)-Style Helles'),
#  (79, 'Dortmunder / European-Style Export'),
#  (80, 'Vienna-Style Lager'),
#  (81, 'German-Style Märzen'),
#  (82, 'German-Style Oktoberfest / Wiesen (Meadow)'),
#  (83, 'European-Style Dark / Münchner Dunkel'),
#  (84, 'German-Style Schwarzbier'),
#  (85, 'Bamberg-Style Märzen Rauchbier'),
#  (86, 'Bamberg-Style Helles Rauchbier'),
#  (87, 'Bamberg-Style Bock Rauchbier'),
#  (88, 'Traditional German-Style Bock'),
#  (89, 'German-Style Heller Bock/Maibock'),
#  (90, 'German-Style Doppelbock'),
#  (91, 'German-Style Eisbock'),
#  (92, 'Kellerbier (Cellar beer) or Zwickelbier - Lager'),
#  (93, 'American-Style Lager'),
#  (94, 'American-Style Light (Low Calorie) Lager'),
#  (95, 'American-Style Low-Carbohydrate Light Lager'),
#  (96, 'American-Style Amber (Low Calorie) Lager'),
#  (97, 'American-Style Premium Lager'),
#  (98, 'American-Style Pilsener'),
#  (99, 'American-Style Ice Lager'),
#  (100, 'American-Style Malt Liquor'),
#  (101, 'American-Style Amber Lager'),
#  (102, 'American-Style Märzen / Oktoberfest'),
#  (103, 'American-Style Dark Lager'),
#  (104, 'Baltic-Style Porter'),
#  (105, 'Australasian, Latin American or Tropical-Style Light Lager'),
#  (106, 'International-Style Pilsener'),
#  (107, 'Dry Lager'),
#  (108, 'Session Beer'),
#  (109, 'American-Style Cream Ale or Lager'),
#  (110, 'California Common Beer'),
#  (111, 'Ginjo Beer or Sake-Yeast Beer'),
#  (112, 'Light American Wheat Ale or Lager with Yeast'),
#  (113, 'Light American Wheat Ale or Lager without Yeast'),
#  (114, 'Fruit Wheat Ale or Lager with or without Yeast'),
#  (115, 'Dark American Wheat Ale or Lager with Yeast'),
#  (116, 'Dark American Wheat Ale or Lager without Yeast'),
#  (117, 'Rye Ale or Lager with or without Yeast'),
#  (118, 'German-Style Rye Ale (Roggenbier) with or without Yeast'),
#  (119, 'Fruit Beer'),
#  (120, 'Field Beer'),
#  (121, 'Pumpkin Beer'),
#  (122, 'Chocolate / Cocoa-Flavored Beer'),
#  (123, 'Coffee-Flavored Beer'),
#  (124, 'Herb and Spice Beer'),
#  (125, 'Specialty Beer'),
#  (126, 'Specialty Honey Lager or Ale'),
#  (127, 'Gluten-Free Beer'),
#  (128, 'Indigenous Beer (Lager or Ale)'),
#  (129, 'Smoke Beer (Lager or Ale)'),
#  (130, 'Experimental Beer (Lager or Ale)'),
#  (131, 'Historical Beer'),
#  (132, 'Wood- and Barrel-Aged Beer'),
#  (133, 'Wood- and Barrel-Aged Pale to Amber Beer'),
#  (134, 'Wood- and Barrel-Aged Dark Beer'),
#  (135, 'Wood- and Barrel-Aged Strong Beer'),
#  (136, 'Wood- and Barrel-Aged Sour Beer'),
#  (137, 'Aged Beer (Ale or Lager)'),
#  (138, 'Other Strong Ale or Lager'),
#  (139, 'Non-Alcoholic (Beer) Malt Beverages'),
#  (140, 'Dry Mead'),
#  (141, 'Semi-Sweet Mead'),
#  (142, 'Sweet Mead'),
#  (143, 'Cyser (Apple Melomel)'),
#  (144, 'Pyment (Grape Melomel)'),
#  (145, 'Other Fruit Melomel'),
#  (146, 'Metheglin'),
#  (147, 'Braggot'),
#  (148, 'Open Category Mead'),
#  (149, 'Common Cider'),
#  (150, 'English Cider'),
#  (151, 'French Cider'),
#  (152, 'Common Perry'),
#  (153, 'Traditional Perry'),
#  (154, 'New England Cider'),
#  (155, 'Fruit Cider'),
#  (156, 'Apple Wine'),
#  (157, 'Other Specialty Cider or Perry'),
#  (158, 'American-Style Imperial Porter'),
#  (159, 'Adambier'),
#  (160, 'Grodziskie'),
#  (161, 'Flavored Malt Beverage'),
#  (162, 'Energy Enhanced Malt Beverage'),
#  (163, 'Double Red Ale'),
#  (164, 'Session India Pale Ale'),
#  (165, 'Contemporary Gose'),
#  (166, 'Dutch-Style Kuit, Kuyt or Koyt'),
#  (167, 'Belgian-style Fruit Beer'),
#  (168, 'Chili Pepper Beer'),
#  (169, 'Mixed Culture Brett Beer'),
#  (170, 'Wild Beer'),
#  (171, 'Juicy or Hazy Pale Ale'),
#  (172, 'Juicy or Hazy India Pale Ale'),
#  (173, 'Juicy or Hazy Imperial or Double India Pale Ale'),
#  (174, 'Contemporary American-Style Pilsener'),
#  (175, 'Classic Australian-Style Pale Ale'),
#  (176, 'Juicy or Hazy Strong Pale Ale'),
#  (177, 'Contemporary Belgian-Style Gueuze Lambic'),
#  (178, 'Franconian-Style Rotbier'),
#  (179, 'American-Style India Pale Lager'),
#  (180, 'Kombucha'),
#  (181, 'Non-Alcoholic Kombucha')]

# %%
# I'm going to choose these 6 styles from the above list to focus on for this project.
# ('Fresh "Wet" Hop Ale', 'American-Style India Pale Ale', 'Imperial or Double India Pale Ale',
#  'Juicy or Hazy Pale Ale', 'Juicy or Hazy India Pale Ale', 'Juicy or Hazy Imperial or Double India Pale Ale' )
ipas = [26,30,31,171,172,173]

# %% [markdown]
# ### Using those 6 style ID's, amass the IPA's breweryDB has listed

# %%
# The breweryDB API returns beers 50 per page
def getBeerPageByStyle(styleID, page):
    method = 'beers/'
    query = prodURL + method
    params = {'styleId': str(styleID), 'p': str(page), 'key': prodKEY,
              'withSocialAccounts': 'Y', 'withIngredients': 'Y', 'withBreweries': 'Y'}
    response = requests.get(query, params)
    
    # parse the response
    if response:  # response==True for codes 200-400, False otherwise
        remaining_calls = response.headers['X-Ratelimit-Remaining'] # 200 API calls per hour is the limit
        return remaining_calls, response.json()
    else: 
        print(f"That GET request with params={params.items()} failed, with code: {response.status_code}")
        print(response.json())
        return 0,0

# %%
# Sample response for style 30 (American IPA)
calls_left, resp = getBeerPageByStyle(30, 1)

print(f'You have {calls_left} daily calls left.')
resp
# Out:
# You have 196 hourly calls left.
# {'currentPage': 1,
#  'data': [{'abv': '7.5',
#    'available': {'description': 'Limited availability.',
#     'id': 2,
#     'name': 'Limited'},
#    'availableId': 2,
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': 'HLM67XR9E3',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2012-01-03 02:41:53',
#      'description': 'Welcome to Dust Bowl Brewing Company located in Turlock, Ca. We are a small brewing company in the Central Valley of California. Our size allows us to have a very personal and passionate connection to each of our beers. We are continuously testing new flavors and styles to develop our selection of beers. Our goal is to help create a thriving beer culture in the Central Valley.\r\n\r\nOur company is a tribute to the strong-willed, gritty people of the Dust Bowl and Great Depression era. Inspired by the families who came west in search of a new start as well as those who stayed behind to weather the storm. This is great beer born of hard times. Storm’s comin’!',
#      'established': '2009',
#      'id': 'Xnf2WT',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/Xnf2WT/upload_3SATfB-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/Xnf2WT/upload_3SATfB-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/Xnf2WT/upload_3SATfB-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/Xnf2WT/upload_3SATfB-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/Xnf2WT/upload_3SATfB-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'Y',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2012-01-03 02:41:53',
#        'forwardingId': 'Xnf2WT',
#        'id': 'lKsltx',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'N',
#        'latitude': 37.5072202,
#        'locality': 'Turlock',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -120.8835209,
#        'name': 'Main Brewery',
#        'openToPublic': 'N',
#        'postalCode': '95380',
#        'region': 'California',
#        'status': 'deleted',
#        'statusDisplay': 'Deleted',
#        'streetAddress': '3000 Fulkerth Rd.',
#        'timezoneId': 'America/Los_Angeles',
#        'updateDate': '2017-08-31 18:57:31',
#        'website': 'http://dustbowlbrewing.com/'},
#       {'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2016-09-09 18:54:16',
#        'id': 'V8Zeed',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'Y',
#        'latitude': 37.5065169,
#        'locality': 'Turlock',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -120.8826756,
#        'name': 'Dust Bowl Brewing Co.',
#        'openToPublic': 'Y',
#        'phone': '209.250.2043',
#        'postalCode': '95380',
#        'region': 'California',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '3000 Fulkerth Rd.',
#        'timezoneId': 'America/Los_Angeles',
#        'updateDate': '2017-08-31 18:59:55',
#        'website': 'http://www.dustbowlbrewing.com',
#        'yearOpened': '2016'}],
#      'name': 'Dust Bowl Brewing Company',
#      'nameShortDisplay': 'Dust Bowl',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2018-11-08 20:38:22',
#      'website': 'http://dustbowlbrewing.com/'}],
#    'createDate': '2015-03-25 20:28:19',
#    'description': 'In August 2012, for the First Year Anniversary at our Tap Room and Restaurant, we decided to take two of our favorite Dust Bowl beers…Galaxy Pale Ale and Son of Wrath Double IPA…and formulate a new IPA recipe using elements from both beers. The result was a delicious, bold IPA with the fruity, citrus character and malt backbone of Son of Wrath, as well as the tropical aroma and easy drinkability of Galaxy Pale. It was so popular with our fans, we decided to brew more.',
#    'ibu': '75',
#    'id': 'xBKAka',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'name': '"Galactic Wrath" IPA',
#    'nameDisplay': '"Galactic Wrath" IPA',
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2015-03-25 20:28:19'},
#   {'abv': '6.6',
#    'available': {'description': 'Available year round as a staple beer.',
#     'id': 1,
#     'name': 'Year Round'},
#    'availableId': 1,
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': 'UJ82YQDSGH',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2013-07-26 18:34:10',
#      'description': 'Working Man Brewing is Livermore’s newest brewery, located at 5542 Brisa Street, just off of Vasco Road.  Getting the brewery up and running has been a labor of love for the owners, taking the better part of 18 months to turn the space into a full production brewery.  We are excited to finally bring our love of beer and commitment to quality to Livermore, the Tri-Valley, and beyond.\r\n\r\nOur story is one of two independent breweries, Mt. Diablo Brewing and Working Man Brewing Company, coming together to work on one common goal.  Both companies were founded by award-winning home brewers who have a passion to bring high quality, well crafted beer that is fresh and local.  A chance meeting brought these working men together; a shared vision now combines forces under one name, Working Man Brewing Company.\r\n\r\nThe company’s brewers have each have spent years working to perfect great beer recipes.  Beer geeks at heart, both will tinker and tweak the ingredients until the product is just right.  The main goal always being to make a beer they could be proud to share and proud to drink. We never let a beer go out the door that we don’t believe in.',
#      'established': '2013',
#      'id': 'H8jawh',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/H8jawh/upload_8EmbmI-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/H8jawh/upload_8EmbmI-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/H8jawh/upload_8EmbmI-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/H8jawh/upload_8EmbmI-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/H8jawh/upload_8EmbmI-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'N',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2013-07-27 14:00:54',
#        'extendedAddress': 'Suite F',
#        'hoursOfOperation': 'Friday 4-7PM\r\nSaturday 12-6PM\r\nSunday 12-4PM',
#        'hoursOfOperationNotes': 'Friday 4-7PM\r\nSaturday 12-6PM\r\nSunday 12-4PM',
#        'id': 'kDhJT9',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'Y',
#        'latitude': 37.697526,
#        'locality': 'Livermore',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -121.725189,
#        'name': 'Main Brewery',
#        'openToPublic': 'Y',
#        'phone': '(925) 269-9622',
#        'postalCode': '94550',
#        'region': 'California',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '5542 Brisa Street',
#        'updateDate': '2014-07-23 19:11:34',
#        'website': 'http://www.workingmanbrewing.com/',
#        'yearOpened': '2013'}],
#      'mailingListUrl': 'http://beer.wickedcode.com/?page_id=641',
#      'name': 'Working Man Brewing Company',
#      'nameShortDisplay': 'Working Man',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2018-11-08 20:57:42',
#      'website': 'http://www.workingmanbrewing.com/'}],
#    'createDate': '2013-07-27 14:02:13',
#    'description': 'This medium amber beer is infused with a blend of 2-row malted barley and caramel malts. Its balance acquired by using a combination of Pacific Northwest hops for bitterness and aroma.',
#    'glass': {'createDate': '2012-01-03 02:41:33', 'id': 5, 'name': 'Pint'},
#    'glasswareId': 5,
#    'ibu': '45',
#    'id': '5UcMBc',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'name': '"Ignition" IPA',
#    'nameDisplay': '"Ignition" IPA',
#    'socialAccounts': [{'createDate': '2013-07-27 14:02:14',
#      'handle': '373182',
#      'id': 2456,
#      'link': 'http://untappd.com/beer/373182',
#      'socialMedia': {'createDate': '2012-01-03 02:41:41',
#       'id': 4,
#       'name': 'Untappd',
#       'website': 'http://www.untappd.com'},
#      'socialMediaId': 4}],
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2015-03-18 18:05:08'},
#   {'abv': '6.7',
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': 'LPWA4KBJSO',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2012-10-23 11:10:10',
#      'description': "Three Notch'd Craft Kitchen & Brewery serves up locally sourced, beer-infused, gourmet food options as well as Three Notch'd craft beer, cider, wine, craft sodas brewed in house, and signature cocktails in a family friendly inviting atmosphere.",
#      'established': '2012',
#      'id': 'X38nDm',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/X38nDm/upload_4AmjeW-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/X38nDm/upload_4AmjeW-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/X38nDm/upload_4AmjeW-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/X38nDm/upload_4AmjeW-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/X38nDm/upload_4AmjeW-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'N',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2012-10-23 11:10:32',
#        'extendedAddress': 'Ste 9',
#        'hoursOfOperation': 'Tue:  4:00pm - 10:00pm\r\nWed:  4:00pm - 10:00pm\r\nThu:  4:00pm - 10:00pm\r\nFri:  3:00pm - 11:00pm\r\nSat:  12:00pm - 11:00pm\r\nSun:  12:00pm - 8:00pm\r\n\r\nTue:  4:00pm - 10:00pm\r\nWed:  4:00pm - 10:00pm\r\nThu:  4:00pm - 10:00pm\r\nFri:  3:00pm - 11:00pm\r\nSat:  12:00pm - 11:00pm\r\nSun:  12:00pm - 8:00pm',
#        'hoursOfOperationNotes': 'Tue:  4:00pm - 10:00pm\r\nWed:  4:00pm - 10:00pm\r\nThu:  4:00pm - 10:00pm\r\nFri:  3:00pm - 11:00pm\r\nSat:  12:00pm - 11:00pm\r\nSun:  12:00pm - 8:00pm\r\n\r\nTue:  4:00pm - 10:00pm\r\nWed:  4:00pm - 10:00pm\r\nThu:  4:00pm - 10:00pm\r\nFri:  3:00pm - 11:00pm\r\nSat:  12:00pm - 11:00pm\r\nSun:  12:00pm - 8:00pm',
#        'id': '9zVaSj',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'N',
#        'latitude': 38.0377921,
#        'locality': 'Charlottesville',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -78.491266,
#        'name': "Three Notch'd Sour House",
#        'openToPublic': 'Y',
#        'phone': '(434) 961-0959',
#        'postalCode': '22903',
#        'region': 'Virginia',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '946 Grady Ave',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2018-06-22 19:01:07',
#        'website': 'http://threenotchdbrewing.com/',
#        'yearOpened': '2012'},
#       {'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2014-08-25 12:04:07',
#        'hoursOfOperation': 'Tue:  4:00pm - 10:00pm\r\nWed:  4:00pm - 10:00pm\r\nThu:  4:00pm - 10:00pm\r\nFri:  3:00pm - 11:00pm\r\nSat:  12:00pm - 11:00pm\r\nSun:  12:00pm - 8:00pm\r\n\r\nTue:  4:00pm - 10:00pm\r\nWed:  4:00pm - 10:00pm\r\nThu:  4:00pm - 10:00pm\r\nFri:  3:00pm - 11:00pm\r\nSat:  12:00pm - 11:00pm\r\nSun:  12:00pm - 8:00pm',
#        'hoursOfOperationNotes': 'Tue:  4:00pm - 10:00pm\r\nWed:  4:00pm - 10:00pm\r\nThu:  4:00pm - 10:00pm\r\nFri:  3:00pm - 11:00pm\r\nSat:  12:00pm - 11:00pm\r\nSun:  12:00pm - 8:00pm\r\n\r\nTue:  4:00pm - 10:00pm\r\nWed:  4:00pm - 10:00pm\r\nThu:  4:00pm - 10:00pm\r\nFri:  3:00pm - 11:00pm\r\nSat:  12:00pm - 11:00pm\r\nSun:  12:00pm - 8:00pm',
#        'id': 'RPBWsF',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'N',
#        'latitude': 38.4487606,
#        'locality': 'Harrisonburg',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -78.8655804,
#        'name': "Three Notch'd Valley Collab House",
#        'openToPublic': 'Y',
#        'phone': '(540) 217-5939',
#        'postalCode': '22801',
#        'region': 'Virginia',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '241 E Market St.',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2018-06-22 19:40:17',
#        'website': 'http://threenotchdbrewing.com/'},
#       {'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2017-06-24 01:05:43',
#        'hoursOfOperation': 'M-Th 4-10pm\r\nF 3-11pm\r\nSat 12-11pm\r\nSun 12-8pm',
#        'hoursOfOperationNotes': 'M-Th 4-10pm\r\nF 3-11pm\r\nSat 12-11pm\r\nSun 12-8pm',
#        'id': 'POtWdo',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'N',
#        'latitude': 37.5643754,
#        'locality': 'Richmond',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -77.472067,
#        'name': "Three Notch'd RVA Collab House",
#        'openToPublic': 'Y',
#        'phone': '4342930610',
#        'postalCode': '23230',
#        'region': 'Virginia',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '2920 West Broad Street',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2018-06-22 18:58:36',
#        'website': 'www.threenb.com',
#        'yearOpened': '2016'},
#       {'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2017-06-24 01:09:32',
#        'hoursOfOperation': 'M-Th 11am-10pm\nF 11am-11pm\nSat 10am-11pm\nSun 10am-11pm',
#        'hoursOfOperationNotes': 'M-Th 11am-10pm\nF 11am-11pm\nSat 10am-11pm\nSun 10am-11pm',
#        'id': '1icKnF',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'N',
#        'latitude': 38.0263256,
#        'locality': 'Charlottesville',
#        'locationType': 'brewpub',
#        'locationTypeDisplay': 'Brewpub',
#        'longitude': -78.4827742,
#        'name': "Three Notch'd Craft House",
#        'openToPublic': 'Y',
#        'phone': '434-293-0610',
#        'postalCode': '22903',
#        'region': 'VA',
#        'status': 'deleted',
#        'statusDisplay': 'Deleted',
#        'streetAddress': '520 2nd Street SE',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2017-08-31 19:03:32',
#        'website': 'www.threenb.com',
#        'yearOpened': '2017'},
#       {'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2018-06-22 18:04:49',
#        'hoursOfOperationExplicit': {'fri': [{'endTime': '11:00pm',
#           'startTime': '11:00am'}],
#         'mon': [{'endTime': '10:00pm', 'startTime': '11:00am'}],
#         'sat': [{'endTime': '11:00pm', 'startTime': '10:00am'}],
#         'sun': [{'endTime': '10:00pm', 'startTime': '10:00am'}],
#         'thu': [{'endTime': '10:00pm', 'startTime': '11:00am'}],
#         'tue': [{'endTime': '10:00pm', 'startTime': '11:00am'}],
#         'wed': [{'endTime': '10:00pm', 'startTime': '11:00am'}]},
#        'hoursOfOperationExplicitString': 'mon-11:00am-10:00pm,tue-11:00am-10:00pm,wed-11:00am-10:00pm,thu-11:00am-10:00pm,fri-11:00am-11:00pm,sat-10:00am-11:00pm,sun-10:00am-10:00pm',
#        'id': 'rznYZg',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'Y',
#        'latitude': 38.0261248,
#        'locality': 'Charlottesville',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -78.4822094,
#        'name': "Three Notch'd Craft Kitchen and Brewery",
#        'openToPublic': 'Y',
#        'phone': '4349563141',
#        'postalCode': '22902',
#        'region': 'Virginia',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '520 2nd St. SE',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2018-08-20 14:40:00',
#        'website': 'https://threenotchdbrewing.com/charlottesville-craft-kitchen-brewery/',
#        'yearOpened': '2017'}],
#      'name': "Three Notch'd Brewing Company",
#      'nameShortDisplay': "Three Notch'd",
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2019-01-23 13:37:51',
#      'website': 'http://threenotchdbrewing.com/'}],
#    'createDate': '2016-06-13 12:19:19',
#    'ibu': '50',
#    'id': 'ETaM11',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'name': '"Roux 40" Red IPA',
#    'nameDisplay': '"Roux 40" Red IPA',
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2016-06-13 12:19:19'},
#   {'abv': '6',
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': '0EXB95JHNU',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2015-10-31 03:37:26',
#      'description': 'It’s inevitable. Robots will take over the earth someday. Until then, our humans will be making award-winning beer. We make a variety of tasty standards and some exceptional seasonal and unique offerings. Here, we embrace the local.  From our home in Jefferson Park right next to Mile High Stadium, to our completely Colorado-made brewing system.  \r\n\r\nStop by for a draw from our 10 barrel system, and there’s a good chance you’ll start to believe. Cheers!',
#      'established': '2015',
#      'id': 'FfMi8U',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/FfMi8U/upload_PjdQ7m-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/FfMi8U/upload_PjdQ7m-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/FfMi8U/upload_PjdQ7m-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/FfMi8U/upload_PjdQ7m-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/FfMi8U/upload_PjdQ7m-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'Y',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2015-10-31 03:37:27',
#        'id': 'o1cTsM',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'Y',
#        'latitude': 39.747316,
#        'locality': 'Denver',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -105.024345,
#        'name': 'Main Brewery',
#        'openToPublic': 'Y',
#        'postalCode': '80211',
#        'region': 'Colorado',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '2924 W 20th Ave.',
#        'timezoneId': 'America/Denver',
#        'updateDate': '2017-08-22 17:01:18',
#        'website': 'http://www.littlemachinebeer.com'}],
#      'name': 'Little Machine Beer',
#      'nameShortDisplay': 'Little Machine Beer',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2018-11-08 23:41:46',
#      'website': 'http://www.littlemachinebeer.com'}],
#    'createDate': '2015-11-03 17:01:42',
#    'ibu': '50',
#    'id': '8f8vqK',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'name': '"Sniff" IPA',
#    'nameDisplay': '"Sniff" IPA',
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2015-11-03 17:01:42'},
#   {'abv': '6.7',
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': 'D81TOF6CK9',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2014-05-09 15:14:48',
#      'description': 'Not All Beers Are Created Equal',
#      'id': 'BiNSTd',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/BiNSTd/upload_S7quAN-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/BiNSTd/upload_S7quAN-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/BiNSTd/upload_S7quAN-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/BiNSTd/upload_S7quAN-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/BiNSTd/upload_S7quAN-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'Y',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2014-05-09 15:19:21',
#        'hoursOfOperation': 'Thursday 4pm to 9pm\r\nFriday 4pm to 9pm\r\nSaturday 12pm to 9pm\r\nSunday 11am to 6pm',
#        'hoursOfOperationNotes': 'Thursday 4pm to 9pm\r\nFriday 4pm to 9pm\r\nSaturday 12pm to 9pm\r\nSunday 11am to 6pm',
#        'id': '2TcMqe',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'Y',
#        'latitude': 41.4735869,
#        'locality': 'Valparaiso',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -87.0797478,
#        'name': 'Four Fathers Brewing, LLC',
#        'openToPublic': 'Y',
#        'phone': '(219) 464-9712',
#        'postalCode': '46385',
#        'region': 'Indiana',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '1555 W Lincolnway Ste 105',
#        'updateDate': '2014-07-23 19:11:34',
#        'website': 'http://www.fourfathersbrewing.com/',
#        'yearOpened': '2014'}],
#      'name': 'Four Fathers Brewing, LLC',
#      'nameShortDisplay': 'Four Fathers',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2018-11-08 22:54:44',
#      'website': 'http://www.fourfathersbrewing.com/'}],
#    'createDate': '2016-05-02 15:09:45',
#    'description': 'White IPA w/ Orange Peel, Coriander, Peaches, & Apricot.',
#    'id': 'EliWWJ',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'name': '#15',
#    'nameDisplay': '#15',
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2016-05-02 15:09:45'},
#   {'abv': '7.1',
#    'available': {'description': 'Limited availability.',
#     'id': 2,
#     'name': 'Limited'},
#    'availableId': 2,
#    'breweries': [{'createDate': '2012-01-03 02:42:12',
#      'description': "Having trained in Germany, we appreciate the artistic freedom we have here in the US. Here creativity is embraced by a fervent core of consumers and we are happy to serve that audience with our experience in traditional methods, selection of choice, often imported ingredients, and the best processing that technology can offer us. We relish the opportunity to please both ourselves and our audience with our flavorful creations.  We've invested more than our lives in this. Take a look at Victory Brewing Company's Beers.",
#      'established': '1996',
#      'id': 'VoKbnS',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/VoKbnS/upload_zV2khl-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/VoKbnS/upload_zV2khl-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/VoKbnS/upload_zV2khl-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/VoKbnS/upload_zV2khl-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/VoKbnS/upload_zV2khl-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'Y',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2012-01-03 02:42:12',
#        'hoursOfOperation': 'Mon:  11:00am - 12:00am\r\nTue:  11:00am - 12:00am\r\nWed:  11:00am - 12:00am\r\nThu:  11:00am - 12:00am\r\nFri:  11:00am - 12:00am\r\nSat:  11:00am - 12:00am\r\nSun:  11:00am - 10:00pm\r\n\r\nBREWERY HOURS (For Shipping and Receiving)\r\n8:00 am to 4:00 pm Monday through Thursday\r\n\r\nRESTAURANT\r\nVisit our Brewpub page.\r\nMonday – Saturday 11:30am – Midnight\r\nSunday 11:30am – 10:00pm\r\n\r\nRETAIL STORE \r\nVisit our online store.\r\n610-873-0881 ext. 206\r\nSunday 11:30am – 8:00pm\r\nMonday -Thursday 11:30am – 8:30pm\r\nFriday – Saturday 11:30am – 10:00pm',
#        'hoursOfOperationNotes': 'Mon:  11:00am - 12:00am\r\nTue:  11:00am - 12:00am\r\nWed:  11:00am - 12:00am\r\nThu:  11:00am - 12:00am\r\nFri:  11:00am - 12:00am\r\nSat:  11:00am - 12:00am\r\nSun:  11:00am - 10:00pm\r\n\r\nBREWERY HOURS (For Shipping and Receiving)\r\n8:00 am to 4:00 pm Monday through Thursday\r\n\r\nRESTAURANT\r\nVisit our Brewpub page.\r\nMonday – Saturday 11:30am – Midnight\r\nSunday 11:30am – 10:00pm\r\n\r\nRETAIL STORE \r\nVisit our online store.\r\n610-873-0881 ext. 206\r\nSunday 11:30am – 8:00pm\r\nMonday -Thursday 11:30am – 8:30pm\r\nFriday – Saturday 11:30am – 10:00pm',
#        'id': 'LSrqUN',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'Y',
#        'latitude': 40.0059213,
#        'locality': 'Downingtown',
#        'locationType': 'brewpub',
#        'locationTypeDisplay': 'Brewpub',
#        'longitude': -75.6941744,
#        'name': 'Main Brewery - Downingtown',
#        'openToPublic': 'Y',
#        'phone': '1-610-873-0881',
#        'postalCode': '19335',
#        'region': 'Pennsylvania',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '420 Acorn Lane',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2015-10-13 19:30:34',
#        'website': 'http://www.victorybeer.com/',
#        'yearOpened': '1996'},
#       {'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2015-08-13 15:28:43',
#        'hoursOfOperation': 'Mon:  11:00am - 12:00am\r\nTue:  11:00am - 12:00am\r\nWed:  11:00am - 12:00am\r\nThu:  11:00am - 12:00am\r\nFri:  11:00am - 12:00am\r\nSat:  11:00am - 12:00am\r\nSun:  11:00am - 10:00pm',
#        'hoursOfOperationNotes': 'Mon:  11:00am - 12:00am\r\nTue:  11:00am - 12:00am\r\nWed:  11:00am - 12:00am\r\nThu:  11:00am - 12:00am\r\nFri:  11:00am - 12:00am\r\nSat:  11:00am - 12:00am\r\nSun:  11:00am - 10:00pm',
#        'id': 'hBiSw9',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'N',
#        'latitude': 39.8446741,
#        'locality': 'Kennett Square',
#        'locationType': 'brewpub',
#        'locationTypeDisplay': 'Brewpub',
#        'longitude': -75.7191314,
#        'name': 'Kennett Square',
#        'openToPublic': 'Y',
#        'phone': '484-730-1870',
#        'postalCode': '19348',
#        'region': 'Pennsylvania',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '650 West Cypress Street',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2015-10-27 17:20:41'},
#       {'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2015-08-13 15:30:37',
#        'id': 'JVRH5a',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'N',
#        'latitude': 39.9519993,
#        'locality': 'Parkesburg',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -75.9361872,
#        'name': 'Main Brewery - Parkesburg',
#        'openToPublic': 'Y',
#        'postalCode': '19365',
#        'region': 'Pennsylvania',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '3127 Lower Valley Road',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2015-10-27 17:20:49'}],
#      'name': 'Victory Brewing Company',
#      'nameShortDisplay': 'Victory',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2018-11-08 18:59:55',
#      'website': 'http://www.victorybeer.com/'}],
#    'createDate': '2014-12-23 13:20:57',
#    'description': 'Citrus and dark fruit characters come through in this well-balanced red ale, which features a caramel malt background to complement its slight bitterness.',
#    'foodPairings': 'Curry, wings, blue cheese',
#    'id': '6VZsVo',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'name': '#429 Red IPA',
#    'nameDisplay': '#429 Red IPA',
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2014-12-23 13:20:57'},
#   {'abv': '6.8',
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': 'I7FEM6YHC0',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2012-11-19 18:46:54',
#      'description': 'In 2008, our founders Luke Bowen and Trevor Hayward met in an accounting class at Villanova University. Realizing that their job prospects were grim due to the recession, they decided to follow their passion and start their own brewery. \r\n\r\nTheir journey took them first to South Bend, Indiana, then to Cooperstown, New York, and finally to Hartford, Connecticut. This exhaustive search landed them a partner who cared as much about craft beer as Luke and Trevor. Today the amazing team at Thomas Hooker Brewing Company works with our founders to craft the highest quality beers possible. \r\n\r\nThe next step for Evil Genius is to build their own brewery. Right now, Luke and Trevor are searching for locations around Philadelphia. As Evil Genius turns 4 in September, we have you, our customers to thank for helping make this dream a reality',
#      'established': '2011',
#      'id': 'PdSE1h',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/PdSE1h/upload_Yxpq59-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/PdSE1h/upload_Yxpq59-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/PdSE1h/upload_Yxpq59-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/PdSE1h/upload_Yxpq59-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/PdSE1h/upload_Yxpq59-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'Y',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2012-11-19 18:48:15',
#        'id': 'MnsgKh',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'Y',
#        'latitude': 39.9757143,
#        'locality': 'Philadelphia',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -75.1341629,
#        'name': 'Main Brewery',
#        'openToPublic': 'Y',
#        'phone': '(484) 961-0247',
#        'region': 'Pennsylvania',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '1727 N Front Street',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2017-04-20 17:53:39',
#        'website': 'http://www.evilgeniusbeer.com/',
#        'yearOpened': '2010'}],
#      'name': 'Evil Genius Beer Company',
#      'nameShortDisplay': 'Evil Genius',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2018-11-08 21:48:19',
#      'website': 'http://www.evilgeniusbeer.com/'}],
#    'createDate': '2016-10-29 22:59:00',
#    'description': '5th anniversary Guava IPA with citra, cascade, and warrior hops.',
#    'ibu': '65',
#    'id': 'uSAFK1',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'name': '#Adulting',
#    'nameDisplay': '#Adulting',
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2016-11-18 19:22:16'},
#   {'abv': '7',
#    'available': {'description': 'Available year round as a staple beer.',
#     'id': 1,
#     'name': 'Year Round'},
#    'availableId': 1,
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': 'Y4WUJ7D9RX',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2012-01-03 02:42:04',
#      'description': 'To handcraft innovative beers with unique and complex tastes; to make a positive impact in our community.  Ohana Brewing Company is an artisanal brewery in the heart of Los Angeles.\r\n\r\nOur slogan is "A fresh face in beer!" Although our production is ultra-small we will pursue a number of strategies to stand out in the craft brewing industry. Our mission is to brew innovative beers with unique and complex tastes - not to just copy what the competition is doing. To that end we are committed to avoiding "repeatability" - i.e. we will not brew any beer more than once in our first full year of operation, i.e. no recipe will be duplicated.',
#      'id': 'nE0YCy',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/nE0YCy/upload_um4GID-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/nE0YCy/upload_um4GID-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/nE0YCy/upload_um4GID-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/nE0YCy/upload_um4GID-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/nE0YCy/upload_um4GID-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'Y',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
# ...
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2017-12-28 15:35:44'},
#   {'abv': '9.9',
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': 'TMUHVCI5PD',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2015-02-09 03:39:17',
#      'description': 'Pigskin is more than a name, it’s an idea. Pigskin represents a feeling, a raw emotion, and a sense of total satisfaction. We deliver a feeling of “Victory in every sip.” It is our tagline and also our foundation. We offer exquisitely crafted beers that satisfy every fan like they just won the big game. We are committed to the “Pigskin Experience”: a top notch taproom and brewery, world class hospitality, and some of the best damn beers in the land. So come join us at Pigskin to watch the game, celebrate after a day of dominating at work, or just kick back and enjoy the high-quality beer you deserve!',
#      'established': '2013',
#      'id': 'oJkeNe',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/oJkeNe/upload_HSpwnC-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/oJkeNe/upload_HSpwnC-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/oJkeNe/upload_HSpwnC-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/oJkeNe/upload_HSpwnC-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/oJkeNe/upload_HSpwnC-squareMedium.png'},
#      'isInBusiness': 'N',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'N',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2015-02-09 03:39:18',
#        'id': 'FGJqvR',
#        'inPlanning': 'N',
#        'isClosed': 'Y',
#        'isPrimary': 'Y',
#        'latitude': 40.0199944,
#        'locality': 'Columbus',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -82.8802974,
#        'name': 'Main Brewery',
#        'openToPublic': 'N',
#        'postalCode': '43230',
#        'region': 'Ohio',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '81 Mill Street',
#        'updateDate': '2019-05-29 19:01:47',
#        'website': 'http://www.pigskinbrewingcompany.com'}],
#      'name': 'Pigskin Brewing Company',
#      'nameShortDisplay': 'Pigskin',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2019-05-29 19:02:01',
#      'website': 'http://www.pigskinbrewingcompany.com'}],
#    'createDate': '2016-01-14 19:25:11',
#    'ibu': '100',
#    'id': 'k6x1Eb',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'name': '12 Gauge',
#    'nameDisplay': '12 Gauge',
#    'srm': {'hex': 'E58500', 'id': 9, 'name': '9'},
#    'srmId': 9,
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2016-01-14 19:25:11'},
#   {'abv': '7',
#    'available': {'description': 'Available at the same time of year, every year.',
#     'id': 4,
#     'name': 'Seasonal'},
#    'availableId': 4,
#    'breweries': [{'createDate': '2013-01-21 22:18:26',
#      'established': '2011',
#      'id': 'Ao55dX',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/Ao55dX/upload_hQSt1r-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/Ao55dX/upload_hQSt1r-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/Ao55dX/upload_hQSt1r-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/Ao55dX/upload_hQSt1r-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/Ao55dX/upload_hQSt1r-squareMedium.png'},
#      'isInBusiness': 'N',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'N',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2013-01-21 22:20:30',
#        'id': 'UqDEcI',
#        'inPlanning': 'N',
#        'isClosed': 'Y',
#        'isPrimary': 'Y',
#        'latitude': 40.3339774,
#        'locality': 'Linglestown',
#        'locationType': 'micro',
#        'locationTypeDisplay': 'Micro Brewery',
#        'longitude': -76.7891375,
#        'name': 'Main Brewery',
#        'openToPublic': 'N',
#        'phone': '(717) 469-5007',
#        'region': 'Pennsylvania',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'timezoneId': 'America/New_York',
#        'updateDate': '2017-07-24 15:01:41',
#        'website': 'http://www.millbock.com/',
#        'yearOpened': '2011'}],
#      'name': 'Millbock Brewing Company',
#      'nameShortDisplay': 'Millbock',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2018-11-08 18:59:55',
#      'website': 'http://www.millbock.com/'}],
#    'createDate': '2013-01-21 22:21:52',
#    'description': '12 Hops of Christmas is our is our celebration brew that we concocted with 12 different hops.  This IPA is light in color and dry to the finish.  Celebrate the 12 Days of Christmas with each of theses...Amarillo, Apollo, Bravo, Citra, Centinninal, Calypso, Cascade, Chinook, Nugget, Millenium, Warrior, and Zythos.',
#    'id': 'TRptV0',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'labels': {'contentAwareIcon': 'https://brewerydb-images.s3.amazonaws.com/beer/TRptV0/upload_GGmj14-contentAwareIcon.png',
#     'contentAwareLarge': 'https://brewerydb-images.s3.amazonaws.com/beer/TRptV0/upload_GGmj14-contentAwareLarge.png',
#     'contentAwareMedium': 'https://brewerydb-images.s3.amazonaws.com/beer/TRptV0/upload_GGmj14-contentAwareMedium.png',
#     'icon': 'https://brewerydb-images.s3.amazonaws.com/beer/TRptV0/upload_GGmj14-icon.png',
#     'large': 'https://brewerydb-images.s3.amazonaws.com/beer/TRptV0/upload_GGmj14-large.png',
#     'medium': 'https://brewerydb-images.s3.amazonaws.com/beer/TRptV0/upload_GGmj14-medium.png'},
#    'name': '12 Hops Of Christmas',
#    'nameDisplay': '12 Hops Of Christmas',
#    'socialAccounts': [{'createDate': '2013-01-21 22:21:53',
#      'handle': '274353',
#      'id': 1852,
#      'link': 'http://untappd.com/beer/274353',
#      'socialMedia': {'createDate': '2012-01-03 02:41:41',
#       'id': 4,
#       'name': 'Untappd',
#       'website': 'http://www.untappd.com'},
#      'socialMediaId': 4}],
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2015-12-17 00:46:28'},
#   {'abv': '5.9',
#    'breweries': [{'brewersAssociation': {'brewersAssocationId': 'GLAHYN1TZO',
#       'isCertifiedCraftBrewer': 'Y'},
#      'createDate': '2012-01-03 02:42:07',
#      'description': 'Hailed as One of the "Top 5 Local Breweries In The Nation", Right Brain Brewery is known for our culinary inspired beers using only whole ingredients, like Asparagus, Cherry Pies, or smoked Mangalitsa Pig Heads. When we\'re not busy fending off pirates on the Boardman Lake we like to throw art shows, concerts, and even yoga classes in our brewery. Some people love us, some people hate us, and others just don\'t understand, but we just want to teach you how to Keep Beer Curious.',
#      'established': '2007',
#      'id': 'wzglGB',
#      'images': {'icon': 'https://brewerydb-images.s3.amazonaws.com/brewery/wzglGB/upload_6g1rcq-icon.png',
#       'large': 'https://brewerydb-images.s3.amazonaws.com/brewery/wzglGB/upload_6g1rcq-large.png',
#       'medium': 'https://brewerydb-images.s3.amazonaws.com/brewery/wzglGB/upload_6g1rcq-medium.png',
#       'squareLarge': 'https://brewerydb-images.s3.amazonaws.com/brewery/wzglGB/upload_6g1rcq-squareLarge.png',
#       'squareMedium': 'https://brewerydb-images.s3.amazonaws.com/brewery/wzglGB/upload_6g1rcq-squareMedium.png'},
#      'isInBusiness': 'Y',
#      'isMassOwned': 'N',
#      'isOrganic': 'N',
#      'isVerified': 'Y',
#      'locations': [{'country': {'createDate': '2012-01-03 02:41:33',
#         'displayName': 'United States',
#         'isoCode': 'US',
#         'isoThree': 'USA',
#         'name': 'UNITED STATES',
#         'numberCode': 840},
#        'countryIsoCode': 'US',
#        'createDate': '2012-01-03 02:42:07',
#        'hoursOfOperation': 'Mon - Wed: 12:00 pm - 12:00 am\r\nThurs - Sat: 11:00 am - 1:00 am\r\nSun: 12:00 pm - 10:00 pm',
#        'hoursOfOperationNotes': 'Mon - Wed: 12:00 pm - 12:00 am\r\nThurs - Sat: 11:00 am - 1:00 am\r\nSun: 12:00 pm - 10:00 pm',
#        'id': 'lEg7Tx',
#        'inPlanning': 'N',
#        'isClosed': 'N',
#        'isPrimary': 'Y',
#        'latitude': 44.749331,
#        'locality': 'Traverse City',
#        'locationType': 'brewpub',
#        'locationTypeDisplay': 'Brewpub',
#        'longitude': -85.620418,
#        'name': 'Main Brewery',
#        'openToPublic': 'Y',
#        'phone': '231-944-1239',
#        'postalCode': '49684',
#        'region': 'Michigan',
#        'status': 'verified',
#        'statusDisplay': 'Verified',
#        'streetAddress': '225 East 16th Street',
#        'updateDate': '2014-07-23 19:11:34',
#        'website': 'http://www.rightbrainbrewery.com/'}],
#      'name': 'Right Brain Brewery',
#      'nameShortDisplay': 'Right Brain',
#      'status': 'verified',
#      'statusDisplay': 'Verified',
#      'updateDate': '2018-11-08 20:23:32',
#      'website': 'http://www.rightbrainbrewery.com/'}],
#    'createDate': '2014-04-29 10:04:17',
#    'id': 'n1oDDP',
#    'isOrganic': 'N',
#    'isRetired': 'N',
#    'labels': {'contentAwareIcon': 'https://brewerydb-images.s3.amazonaws.com/beer/n1oDDP/upload_GSX07n-contentAwareIcon.png',
#     'contentAwareLarge': 'https://brewerydb-images.s3.amazonaws.com/beer/n1oDDP/upload_GSX07n-contentAwareLarge.png',
#     'contentAwareMedium': 'https://brewerydb-images.s3.amazonaws.com/beer/n1oDDP/upload_GSX07n-contentAwareMedium.png',
#     'icon': 'https://brewerydb-images.s3.amazonaws.com/beer/n1oDDP/upload_GSX07n-icon.png',
#     'large': 'https://brewerydb-images.s3.amazonaws.com/beer/n1oDDP/upload_GSX07n-large.png',
#     'medium': 'https://brewerydb-images.s3.amazonaws.com/beer/n1oDDP/upload_GSX07n-medium.png'},
#    'name': '1225 IPA',
#    'nameDisplay': '1225 IPA',
#    'status': 'verified',
#    'statusDisplay': 'Verified',
#    'style': {'abvMax': '7.5',
#     'abvMin': '6.3',
#     'category': {'createDate': '2012-03-21 20:06:45',
#      'id': 3,
#      'name': 'North American Origin Ales'},
#     'categoryId': 3,
#     'createDate': '2012-03-21 20:06:45',
#     'description': 'American-style India pale ales are perceived to have medium-high to intense hop bitterness, flavor and aroma with medium-high alcohol content. The style is further characterized by floral, fruity, citrus-like, piney, resinous, or sulfur-like American-variety hop character. Note that one or more of these American-variety hop characters is the perceived end, but the hop characters may be a result of the skillful use of hops of other national origins. The use of water with high mineral content results in a crisp, dry beer. This pale gold to deep copper-colored ale has a full, flowery hop aroma and may have a strong hop flavor (in addition to the perception of hop bitterness). India pale ales possess medium maltiness which contributes to a medium body. Fruity-ester flavors and aromas are moderate to very strong. Diacetyl can be absent or may be perceived at very low levels. Chill and/or hop haze is allowable at cold temperatures. (English and citrus-like American hops are considered enough of a distinction justifying separate American-style IPA and English-style IPA categories or subcategories. Hops of other origins may be used for bitterness or approximating traditional American or English character. See English-style India Pale Ale',
#     'fgMax': '1.018',
#     'fgMin': '1.012',
#     'ibuMax': '70',
#     'ibuMin': '50',
#     'id': 30,
#     'name': 'American-Style India Pale Ale',
#     'ogMin': '1.06',
#     'shortName': 'American IPA',
#     'srmMax': '14',
#     'srmMin': '6',
#     'updateDate': '2015-04-07 15:26:37'},
#    'styleId': 30,
#    'updateDate': '2015-12-17 11:37:00'}],
#  'numberOfPages': 198,
#  'status': 'success',
#  'totalResults': 9884}

# %%
# Show the 50 beers on that first style 30 page, along with their brewery.
#  (Only going to use the first brewer listed, in the case where there are more than one for the beer.  Cleaner.)
[(beer['breweries'][0]['name'], beer['name']) for beer in resp['data']]
# Out:
# [('Dust Bowl Brewing Company', '"Galactic Wrath" IPA'),
#  ('Working Man Brewing Company', '"Ignition" IPA'),
#  ("Three Notch'd Brewing Company", '"Roux 40" Red IPA'),
#  ('Little Machine Beer', '"Sniff" IPA'),
#  ('Four Fathers Brewing, LLC', '#15'),
#  ('Victory Brewing Company', '#429 Red IPA'),
#  ('Evil Genius Beer Company', '#Adulting'),
#  ('Ohana Brewing Co', '#Hashtag Hops IPA'),
#  ('Thomas Hooker Brewing', '#NOFILTER IPA'),
#  ('Mikkeller', '#Overtime IPA'),
#  ('Three Floyds Brewing Company', '$600 Lizard Shoes'),
#  ('Dry Ground Brewing Co.', "'37 Flood"),
#  ('4 Noses Brewing Company', "'Bout Damn Time"),
#  ('Lawrence Beer Company', "'Lectric"),
#  ('Lawrence Beer Company', "'Lectric IPA"),
#  ('Isley Brewing Company', "'Scott's Addition' India Pale Ale"),
#  ('Stony Creek Brewery', '(401) India Pale Ale'),
#  ('(512) Brewing Company', '(512) IPA'),
#  ('(512) Brewing Company', '(512) Juicy IPA'),
#  ('(512) Brewing Company', '(512) SMaSH Mosaic'),
#  ('(512) Brewing Company', '(512) White IPA'),
#  ('Stony Creek Brewery', '(860) India Pale Ale'),
#  ('Coppertail Brewing Co.', '(KU)Jenga Smash'),
#  ('Sloop Brewing', '(No) Pumpkin'),
#  ('Fairhope Brewing Company', '(Take The) Causeway IPA'),
#  ('RAR Brewing', "(un) Wanted DM's"),
#  ('Lincoln Brewing Co.', '.58 Caliber'),
#  ('The Lost Borough Brewing Co.', '007 Undercover IPA'),
#  ('Stone Brewing', '05.30.16 Tangerine IPA'),
#  ('Brew by Numbers', '05|18 IPA - Galaxy & Nelson'),
#  ('Jailbreak Brewing Company', '0Day IPA'),
#  ('Booze Brothers Brewing Co.', '1-800-Tropics'),
#  ('10 Barrel Brewing Company', '10 Barrel OG. Wheat IPA'),
#  ('The Manhattan Project Beer Company', '10 Nanoseconds'),
#  ('Spiteful Brewing', '10-9 Bike Messenger Appreciation IPA'),
#  ('Yazoo Brewing Company', '10-Year IPA'),
#  ('White Rabbit Brewing Company', '10/6th IPA'),
#  ('Pact Beer Co.', '100 Acres IPA'),
#  ('Harpoon Brewery', '100 Barrel Series #49 - Brown IPA'),
#  ('Big Beach Brewing', '100 Daze IPA'),
#  ('Redwood Curtain Brewing', '100 Galaxies India Pale Ale'),
#  ('Lupulin Brewing Co.', '100 Spoke IPA'),
#  ("Rapp's Barren Brewing Company", '1000k IPA'),
#  ('Hidden Sands Brewery', "107' India Pale Ale"),
#  ('Finger Lakes Beer Company', '11/11 India Pale Ale'),
#  ('Crow Peak Brewing Company', '11th Hour IPA'),
#  ('Smartmouth Brewing Company', '12 Days of Dry Hop'),
#  ('Pigskin Brewing Company', '12 Gauge'),
#  ('Millbock Brewing Company', '12 Hops Of Christmas'),
#  ('Right Brain Brewery', '1225 IPA')]

# %%
resp.keys()
# Out:
# dict_keys(['currentPage', 'numberOfPages', 'totalResults', 'data', 'status'])

# %%
# Use response['numberOfPages'] to learn how many calls to make to each style
pages = resp['numberOfPages']
pages
# Out:
# 198

# %%
def growDF(df, styleID, start_page, num_pages=10):  # there's a rate limit like 10/sec on brewerydb
    """Build a pandas DataFrame for each IPA style."""
    for i in range(num_pages):
        limit, beer_data = getBeerPageByStyle(styleID, start_page+i)
        print(f'You have {limit} calls left today.')
        if beer_data:  # This will evaluate to False if the GET method failed
            df = df.append(pd.DataFrame(beer_data['data']))
    return df

# %%
# Initialize a DF with page 1 of style 30
style_30_df = pd.DataFrame(resp['data'])

style_30_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 28 columns):
# abv                          45 non-null object
# available                    21 non-null object
# availableId                  21 non-null float64
# breweries                    50 non-null object
# createDate                   50 non-null object
# description                  38 non-null object
# foodPairings                 1 non-null object
# glass                        12 non-null object
# glasswareId                  12 non-null float64
# ibu                          30 non-null object
# id                           50 non-null object
# ingredients                  1 non-null object
# isOrganic                    50 non-null object
# isRetired                    50 non-null object
# labels                       22 non-null object
# name                         50 non-null object
# nameDisplay                  50 non-null object
# originalGravity              8 non-null object
# servingTemperature           8 non-null object
# servingTemperatureDisplay    8 non-null object
# socialAccounts               8 non-null object
# srm                          8 non-null object
# srmId                        8 non-null float64
# status                       50 non-null object
# statusDisplay                50 non-null object
# style                        50 non-null object
# styleId                      50 non-null int64
# updateDate                   50 non-null object
# dtypes: float64(3), int64(1), object(24)
# memory usage: 11.0+ KB

# %% [markdown]
# Well, that stinks that only 1 of the first 50 IPA's has ingredients listed, but at least 38 of them have descriptions, which maybe can be analyzed for keywords like ingredients.

# %%
# concatenate vertically pages 2-198
##  NOTE THAT THIS WILL USE ALL YOUR CALLS UP FOR A DAY, FOR STYLE 30 ##
style_30_df = growDF(style_30_df, styleID=30, start_page=2, num_pages=197)

# %%
len(style_30_df)

# %%
style_30_df.to_pickle('style_30_df.pkl')

# %% [markdown]
# ### So that's it for the largest style, #30, and that's it for API calls for the day.
# ### Here's the encapsulated routine for the other 5 styles:

# %%
ipas.remove(30)

ipas
# Out:
# [26, 31, 171, 172, 173]

# %%
for ipa in ipas:
    # initialize a pd DF from the first page of the style
    calls_left, resp = getBeerPageByStyle(ipa, page=1)
    print(f'You have {calls_left} daily calls left.')
    df = pd.DataFrame(resp['data'])
    # see how many total pages to query
    pages = resp['numberOfPages']
    df = growDF(df, styleID=ipa, start_page=2, num_pages=pages-1)
    # pickle the resulting df
    print(f'Pickling {len(df)} style {ipa} IPAs to "style_{ipa}_df.pkl"')
    df.to_pickle('style_' + str(ipa) + '_df.pkl')
